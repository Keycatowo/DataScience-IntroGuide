# %% [markdown]
# # 爬取PTT文章
# 在這份範例中，會透過在PTT網站上爬取文章的內容，為你示範如何透過網頁爬蟲來取得網頁上的資料。

# %% [markdown]
# ## 爬取單一文章內容

# %% [markdown]
# ### 使用`request`取得網頁內容
# + `request.get(url)`: 使用GET方式取得網頁內容
# + 回傳的物件為`Response`型態，可以透過`Response.text`取得網頁內容
#     + 若狀態碼為`200`：表示成功取得網頁內容
#     + 若狀態碼為`4xx`：通常是使用者端的某些問題而導致沒有收到內容
#     + 若狀態碼為`5xx`：通常是伺服器端的某些問題而導致沒有收到內容

# %%
import requests # requests是一個Python HTTP請求套件，可以用來向網站發送各種HTTP請求

URL = "https://www.ptt.cc/bbs/joke/M.1380444935.A.7A8.html" # PTT joke版某篇文章的網址

response = requests.get(URL)
response # <Response [200]> 代表成功
# Out:
# <Response [200]>

# %%
# 透過 text 屬性可以取得網頁原始碼
print(response.text)

# %% [markdown]
# ### 使用`BeautifulSoup`解析網頁內容
# 若是直接查看未解析過的網頁原始碼，會發現內容非常雜亂，且不易閱讀。
# 因此我們需要使用`BeautifulSoup`來協助我們，將網頁內容解析成格式化的資料，以利後續的處理。
# + `BeautifulSoup(response.text, "lxml")`: 將網頁內容解析成格式化的資料，其中的參數如下
#     + `response.text`: 網頁內容
#     + `lxml`: 解析器，也有其他選項，例如：
#         + `lxml`: 使用`lxml`解析器
#         + `html.parser`: 使用`html.parser`解析器
#         + `html5lib`: 使用`html5lib`解析器

# %%
from bs4 import BeautifulSoup # 注意這邊是從bs4這個套件中，引入BeautifulSoup這個類別

soup = BeautifulSoup(response.text, "html.parser")
soup # 格式化排版後的網頁內容
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Fw: [問卦] 英文真的重要嗎 - 看板 joke - 批踢踢實業坊</title>
# <meta content="all" name="robots"/>
# <meta content="Ptt BBS 批踢踢" name="keywords"/>
# <meta content="作者: milkcake (光良的星星) 看板: Gossiping
# 標題: Re: [問卦] 英文真的重要嗎
# 時間: Sun Sep 29 16:26:31 2013
# 本人曾在高雄某外商公司(美商)工作過兩年
# 期間幾乎沒講過英文
# " name="description"/>
# <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
# <meta content="Fw: [問卦] 英文真的重要嗎" property="og:title"/>
# <meta content="作者: milkcake (光良的星星) 看板: Gossiping
# 標題: Re: [問卦] 英文真的重要嗎
# 時間: Sun Sep 29 16:26:31 2013
# 本人曾在高雄某外商公司(美商)工作過兩年
# 期間幾乎沒講過英文
# " property="og:description"/>
# <link href="https://www.ptt.cc/bbs/joke/M.1380444935.A.7A8.html" rel="canonical"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/joke/index.html"><span class="board-label">看板 </span>joke</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="navigation-container">
# <div class="bbs-content" id="navigation">
# <a class="board" href="/bbs/joke/index.html">返回看板</a>
# <div class="bar"></div>
# </div>
# </div>
# <div id="main-container">
# <div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">lihsien (希洛)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">joke</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Fw: [問卦] 英文真的重要嗎</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Sep 29 16:55:33 2013</span></div>
# <span class="f2">※ [本文轉錄自 <a href="/bbs/Gossiping/M.1380443196.A.FE3.html" rel="noreferrer noopener nofollow" target="_blank">Gossiping 看板 #1IH-Gy_Z</a> ]
# </span>
# 作者: milkcake (光良的星星) 看板: Gossiping
# 標題: Re: [問卦] 英文真的重要嗎
# 時間: Sun Sep 29 16:26:31 2013
#
#
# 本人曾在高雄某外商公司(美商)工作過兩年
#
# 期間幾乎沒講過英文
#
# 不論是客戶或對老闆做簡報
#
# 客戶比較沒話說，畢竟在台灣服務 客人也是以台灣居多
#
# 即使偶爾遇到外國人也大都是用中文交談
#
# 至於對上級報告(包括定期會議)
#
# 由於本人英文也沒有很好，所以乾脆直接講中文
#
# 反正也都聽得懂
#
# 真的有能力別人要來求你，也是會用你習慣的語言
#
# 所以具備專業能力才是最重要的
#
# 英文能力我倒覺得是第二順位
#
# 畢竟人家開公司是為了賺錢
#
# 用膝蓋想也知道是要優先錄用有能力但英文沒那麼好的
#
# 而不是英文好但什麼都不會
#
# 這是我在麥當勞打工後的經驗
#
# 謝謝大家
#
#
#
#
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 140.115.42.112
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cephalitis</span><span class="f3 push-content">:XDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:27
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Szss</span><span class="f3 push-content">:倒數第二句??</span><span class="push-ipdatetime"> 09/29 16:27
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ccker</span><span class="f3 push-content">:ㄜ..</span><span class="push-ipdatetime"> 09/29 16:27
# </span></div>
# 麥當勞是美商
# <span class="f2">※ 編輯: milkcake        來自: 140.115.42.112       (09/29 16:28)
# </span><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Level</span><span class="f3 push-content">:美商英文能力不好怎麼進的....</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Szss</span><span class="f3 push-content">:能夠當下判斷出綠皮馬鈴薯才重要</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mori9455</span><span class="f3 push-content">:XDDDDD</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">kent</span><span class="f3 push-content">:有好笑到</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">WhiteMage</span><span class="f3 push-content">:麥當勞打工......</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Dulcia</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Level</span><span class="f3 push-content">:........麥當勞 靠</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">srxcomtx</span><span class="f3 push-content">:.........</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">eggcakepie</span><span class="f3 push-content">:。。。。。。</span><span class="push-ipdatetime"> 09/29 16:28
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">tyrande</span><span class="f3 push-content">:這篇很瓦風</span><span class="push-ipdatetime"> 09/29 16:29
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">chengweirh</span><span class="f3 push-content">:..................</span><span class="push-ipdatetime"> 09/29 16:29
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zephyrias33</span><span class="f3 push-content">:會覺得某件事不重要都是沒辦法把那件事作好才安慰自己</span><span class="push-ipdatetime"> 09/29 16:29
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Ximcra</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:29
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">KG29911069</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 16:29
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">pegy3920</span><span class="f3 push-content">:就是有這種文，八卦板才有活力</span><span class="push-ipdatetime"> 09/29 16:29
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">starport</span><span class="f3 push-content">:今天滿是這種靠北文章XDDDDD</span><span class="push-ipdatetime"> 09/29 16:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">maxxV3</span><span class="f3 push-content">:哈哈</span><span class="push-ipdatetime"> 09/29 16:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">alentek</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tcpic</span><span class="f3 push-content">:靠杯喔害我認真了XD</span><span class="push-ipdatetime"> 09/29 16:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">HermesKing</span><span class="f3 push-content">:XDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:31
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">wwe2646162</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 16:31
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">momoisacow</span><span class="f3 push-content">:靠北 我也認真看完了</span><span class="push-ipdatetime"> 09/29 16:31
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">maninpink</span><span class="f3 push-content">:這篇超讚的啦XDDDDD</span><span class="push-ipdatetime"> 09/29 16:31
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">asd2260123</span><span class="f3 push-content">:靠杯喔</span><span class="push-ipdatetime"> 09/29 16:31
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">speedman</span><span class="f3 push-content">:靠杯，我竟然認真了 XD</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mike110100</span><span class="f3 push-content">:認真文推</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kipi91718</span><span class="f3 push-content">:靠北 XDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">terry955048</span><span class="f3 push-content">:在法商做簡報還不是不用法文就可以過          家樂福</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sellgd</span><span class="f3 push-content">:反串文 puchline在麥當勞</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">upyours</span><span class="f3 push-content">:這文廢到好笑</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">m21423</span><span class="f3 push-content">:麥當勞打工還要簡報喔</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">chaudieuer</span><span class="f3 push-content">:XDDDDD沒看推文我還沒發現 倒數第二行</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">liaon98</span><span class="f3 push-content">:XDDDDD</span><span class="push-ipdatetime"> 09/29 16:32
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">hellomen</span><span class="f3 push-content">:靠杯  看完了XD</span><span class="push-ipdatetime"> 09/29 16:33
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">followwar</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:33
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">gungunit</span><span class="f3 push-content">:XDDDDDD</span><span class="push-ipdatetime"> 09/29 16:33
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">voyhanxu</span><span class="f3 push-content">:哈哈哈 笑死我了XD</span><span class="push-ipdatetime"> 09/29 16:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">TokyoHot5566</span><span class="f3 push-content">:ㄏㄏ</span><span class="push-ipdatetime"> 09/29 16:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">kutkin</span><span class="f3 push-content">:你到底要跟誰簡報?</span><span class="push-ipdatetime"> 09/29 16:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">adm123</span><span class="f3 push-content">:全家是日商？</span><span class="push-ipdatetime"> 09/29 16:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">poppipe</span><span class="f3 push-content">:Joke文</span><span class="push-ipdatetime"> 09/29 16:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">uzumaki</span><span class="f3 push-content">:有靠杯到XDXDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Leeng</span><span class="f3 push-content">:幹你贏了XDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">TZUYIC</span><span class="f3 push-content">:都是為你 都是為你 麥當勞都是為你</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">s92228</span><span class="f3 push-content">:XDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">carlos5978</span><span class="f3 push-content">:靠霸 XDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">newewew</span><span class="f3 push-content">:靠杯 害我認真XDDD</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">JT07</span><span class="f3 push-content">:你太有才了！</span><span class="push-ipdatetime"> 09/29 16:35
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zzxcasd</span><span class="f3 push-content">:你贏了</span><span class="push-ipdatetime"> 09/29 16:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">space20021</span><span class="f3 push-content">:XDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">chungyiju</span><span class="f3 push-content">:XDD</span><span class="push-ipdatetime"> 09/29 16:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Oxhorn</span><span class="f3 push-content">:炸個薯條還得作簡報XDDDD</span><span class="push-ipdatetime"> 09/29 16:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">r30385</span><span class="f3 push-content">:..............................................</span><span class="push-ipdatetime"> 09/29 16:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">beyondboy</span><span class="f3 push-content">:好強大的文章 XD</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">johtom811113</span><span class="f3 push-content">:XDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">hey0703</span><span class="f3 push-content">:你淫惹</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">oo0</span><span class="f3 push-content">:XXXXXXXXXXXXXXXXXXXXXXXXXDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">imrbo</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">OpenGoodHate</span><span class="f3 push-content">:有笑有推</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">KCKCLIN</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:37
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">msnskyline</span><span class="f3 push-content">:BIG MAC !  BIG MAC !</span><span class="push-ipdatetime"> 09/29 16:38
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">duolon</span><span class="f3 push-content">:英文是你要搶老外的錢的重要基礎 就好像你要搶日本人錢就需</span><span class="push-ipdatetime"> 09/29 16:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tper8042</span><span class="f3 push-content">:跟親鏡子有得拚</span><span class="push-ipdatetime"> 09/29 16:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">faxy</span><span class="f3 push-content">:ψ-(._. )&gt;</span><span class="push-ipdatetime"> 09/29 16:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rarirurero</span><span class="f3 push-content">:靠腰 後勁好強 XDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">PPPGGG</span><span class="f3 push-content">:己霸婚</span><span class="push-ipdatetime"> 09/29 16:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sandra83520</span><span class="f3 push-content">:有笑有推XDDD</span><span class="push-ipdatetime"> 09/29 16:39
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">duolon</span><span class="f3 push-content">:要日文一樣....[用不到?那是你不會用]</span><span class="push-ipdatetime"> 09/29 16:39
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">WEDI</span><span class="f3 push-content">:我笑了。</span><span class="push-ipdatetime"> 09/29 16:39
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">z09211290</span><span class="f3 push-content">:XDD</span><span class="push-ipdatetime"> 09/29 16:39
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">chiyaki</span><span class="f3 push-content">:XDD</span><span class="push-ipdatetime"> 09/29 16:39
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">adexaut</span><span class="f3 push-content">:浪費我時間</span><span class="push-ipdatetime"> 09/29 16:40
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">signm</span><span class="f3 push-content">:幹，後勁好強，幾霸婚</span><span class="push-ipdatetime"> 09/29 16:40
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">chewzhang</span><span class="f3 push-content">:好煩XDDDDD</span><span class="push-ipdatetime"> 09/29 16:40
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">wmke</span><span class="f3 push-content">:有笑有推</span><span class="push-ipdatetime"> 09/29 16:40
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cmid05</span><span class="f3 push-content">:XDD</span><span class="push-ipdatetime"> 09/29 16:40
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">qscxz</span><span class="f3 push-content">:靠杯 麥當勞 XDD</span><span class="push-ipdatetime"> 09/29 16:41
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">NANAer</span><span class="f3 push-content">:靠XDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:41
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">simonds</span><span class="f3 push-content">:GJ !</span><span class="push-ipdatetime"> 09/29 16:41
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">gotohikaru</span><span class="f3 push-content">:.....XD</span><span class="push-ipdatetime"> 09/29 16:41
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">proletariat</span><span class="f3 push-content">:噗哧!說得很有道理!</span><span class="push-ipdatetime"> 09/29 16:42
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">mengche</span><span class="f3 push-content">:麥當勞工讀生要對客戶對老闆做簡報嗎?又是個滿口謊言的騜.</span><span class="push-ipdatetime"> 09/29 16:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jeffreyshe</span><span class="f3 push-content">:XDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cokellen</span><span class="f3 push-content">:有笑有推</span><span class="push-ipdatetime"> 09/29 16:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">PIGUms9</span><span class="f3 push-content">:也太好笑XDD</span><span class="push-ipdatetime"> 09/29 16:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">monkjohnny</span><span class="f3 push-content">:大推，八卦版需要你啊！</span><span class="push-ipdatetime"> 09/29 16:42
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">olalo</span><span class="f3 push-content">:好笑，但是舉例很爛...</span><span class="push-ipdatetime"> 09/29 16:43
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">yuan720</span><span class="f3 push-content">:殺小!!!</span><span class="push-ipdatetime"> 09/29 16:43
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sellgd</span><span class="f3 push-content">:向客人解說每個餐的內容 就是簡報啊</span><span class="push-ipdatetime"> 09/29 16:43
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">bala73</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:43
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">sellgd</span><span class="f3 push-content">:用餐時間緊迫不能說太久 就是簡報</span><span class="push-ipdatetime"> 09/29 16:43
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">william307</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:43
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">goshfju</span><span class="f3 push-content">:專業</span><span class="push-ipdatetime"> 09/29 16:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">abxtpml56</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rhino0314</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">woajw</span><span class="f3 push-content">:靠杯 XDDD</span><span class="push-ipdatetime"> 09/29 16:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">arhuro</span><span class="f3 push-content">:後勁好強的回馬槍!</span><span class="push-ipdatetime"> 09/29 16:45
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jackson517</span><span class="f3 push-content">:XDD</span><span class="push-ipdatetime"> 09/29 16:45
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sty0322</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:45
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">CILOHAKROW</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:46
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ffaarr</span><span class="f3 push-content">:XDDDDDD</span><span class="push-ipdatetime"> 09/29 16:46
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">saijuk</span><span class="f3 push-content">:你贏了</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lineagjason</span><span class="f3 push-content">:幹  我笑了</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">BBBroflovski</span><span class="f3 push-content">:XDDD</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ffaarr</span><span class="f3 push-content">:請容我簡報一下今天的新套餐。</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">milicic2103</span><span class="f3 push-content">:我笑了</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">qn</span><span class="f3 push-content">:哈哈</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">THH</span><span class="f3 push-content">:XDDDDDDDDDDDD  你贏了</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">ams9</span><span class="f3 push-content">:所以你的專業能力是啥?</span><span class="push-ipdatetime"> 09/29 16:47
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">PePePeace</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:48
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tokyoto</span><span class="f3 push-content">:用英文點餐的老外你會跟他說 阿鬼 你還是說中文嗎？</span><span class="push-ipdatetime"> 09/29 16:48
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rexlin</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:48
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cjoe</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jack50712</span><span class="f3 push-content">:XDDDDDD</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">billy2769</span><span class="f3 push-content">:XD 害我晚餐想吃麥當勞了</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ziso</span><span class="f3 push-content">:優質廢文!!!</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">dddddd67</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">wowyoyoman</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDD你讓我笑了!!!!</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">c230</span><span class="f3 push-content">:XDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">snowy1045</span><span class="f3 push-content">:xdddddddddd</span><span class="push-ipdatetime"> 09/29 16:49
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">js9150812</span><span class="f3 push-content">:推</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">reaper8046</span><span class="f3 push-content">:You, waste my time!</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">JCS15</span><span class="f3 push-content">:疑  好像沒錯XD</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">iGao</span><span class="f3 push-content">:今天晚餐就來兩個小麥克好了</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">a109250405</span><span class="f3 push-content">:繼上一篇親親要閉眼後 又一個溫馨文 XD</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lihsien</span><span class="f3 push-content">:XDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ekoj</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">greatkevin</span><span class="f3 push-content">:有笑有推</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">zs17</span><span class="f3 push-content">:笑死我了XDDDDDD</span><span class="push-ipdatetime"> 09/29 16:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">liyuoh</span><span class="f3 push-content">:靠北已笑</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">coyoteY</span><span class="f3 push-content">:俺服了~把這篇文印下來去跟老闆要求加薪吧~XDD</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lolic</span><span class="f3 push-content">:xDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">nightstory</span><span class="f3 push-content">:肯德基的全部站出來！</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ericleft</span><span class="f3 push-content">:好文</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Xhocer</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lairx</span><span class="f3 push-content">:有笑有推</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">t1018</span><span class="f3 push-content">:倒數第二句讓我笑翻！</span><span class="push-ipdatetime"> 09/29 16:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">NightMoon33</span><span class="f3 push-content">:有人想轉joke版嗎?XDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:52
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ms0007912</span><span class="f3 push-content">:鋪疵</span><span class="push-ipdatetime"> 09/29 16:52
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">stamina0304</span><span class="f3 push-content">:認真的嗎</span><span class="push-ipdatetime"> 09/29 16:52
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Leoreo</span><span class="f3 push-content">:家樂福:</span><span class="push-ipdatetime"> 09/29 16:52
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">organ63521</span><span class="f3 push-content">:-.-</span><span class="push-ipdatetime"> 09/29 16:52
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">F2012</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">nashmvp</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 16:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">dio112400</span><span class="f3 push-content">:大笑</span><span class="push-ipdatetime"> 09/29 16:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">puppetired</span><span class="f3 push-content">:好煩喔XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Crazyfire</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">seemoon2000</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">pikakami</span><span class="f3 push-content">:美商                                             7-11</span><span class="push-ipdatetime"> 09/29 16:54
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">lihsien</span><span class="f3 push-content">:借轉joke</span><span class="push-ipdatetime"> 09/29 16:54
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tensinya</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:54
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">NiceGuyOrz</span><span class="f3 push-content">:.........</span><span class="push-ipdatetime"> 09/29 16:54
# </span></div>
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span><span class="f2">※ 轉錄者: lihsien (118.171.118.91), 時間: 09/29/2013 16:55:33
# </span><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rocksunnylim</span><span class="f3 push-content">:XDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:58
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">rhino0314</span><span class="f3 push-content">:再推一次</span><span class="push-ipdatetime"> 09/29 16:59
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">showpon</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 17:05
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cjoe</span><span class="f3 push-content">:再推</span><span class="push-ipdatetime"> 09/29 17:08
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">nvalue</span><span class="f3 push-content">:XDDDDDDD</span><span class="push-ipdatetime"> 09/29 17:11
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">xczh</span><span class="f3 push-content">:這應該害英文不好的人白高興一下 XD</span><span class="push-ipdatetime"> 09/29 17:13
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">beyondboy</span><span class="f3 push-content">:再推~XD</span><span class="push-ipdatetime"> 09/29 17:20
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">syric</span><span class="f3 push-content">:推XDD</span><span class="push-ipdatetime"> 09/29 17:22
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">allen911007</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 17:23
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">jinkela1</span><span class="f3 push-content">:還有人法文不好卻在最大法商家樂福上班哦 XD</span><span class="push-ipdatetime"> 09/29 17:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tommy2474578</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 18:05
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">eggimage</span><span class="f3 push-content">:真中肯</span><span class="push-ipdatetime"> 09/29 18:11
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">sing129</span><span class="f3 push-content">:幹   害我白開心了</span><span class="push-ipdatetime"> 09/29 18:16
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mimi1020b</span><span class="f3 push-content">:朝聖</span><span class="push-ipdatetime"> 09/29 18:17
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">hikki430</span><span class="f3 push-content">:XD 法商家樂福</span><span class="push-ipdatetime"> 09/29 18:25
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">Ekmund</span><span class="f3 push-content">:靠XDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 18:51
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">gama1314555</span><span class="f3 push-content">:又是個 逼妹逼妹 !!!</span><span class="push-ipdatetime"> 09/29 18:56
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">angel0328</span><span class="f3 push-content">:...</span><span class="push-ipdatetime"> 09/29 18:56
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">q13461346</span><span class="f3 push-content">:XDDDDD</span><span class="push-ipdatetime"> 09/29 19:10
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Hua0722</span><span class="f3 push-content">:前面看的覺得好屌，後來想想我在就可版就想說結局...</span><span class="push-ipdatetime"> 09/29 19:19
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">gx9900824</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 19:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">XDboy</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 19:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">blahblah</span><span class="f3 push-content">:過來人的經驗啊!(筆記</span><span class="push-ipdatetime"> 09/29 20:01
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">satoranbo</span><span class="f3 push-content">:美商賀寶芙之類的也行啊XD</span><span class="push-ipdatetime"> 09/29 20:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">virve</span><span class="f3 push-content">:XDDDDD</span><span class="push-ipdatetime"> 09/29 20:30
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Aries800419</span><span class="f3 push-content">:XDD</span><span class="push-ipdatetime"> 09/29 20:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">as87452911</span><span class="f3 push-content">:害我認真XDDDDD</span><span class="push-ipdatetime"> 09/29 20:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">qscxz</span><span class="f3 push-content">: ＮＯＴ　ＢＡＤ！</span><span class="push-ipdatetime"> 09/29 20:50
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">LoveBea</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 20:55
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">JhanWayne</span><span class="f3 push-content">:有笑有推~</span><span class="push-ipdatetime"> 09/29 21:01
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">azrael1011</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 21:10
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">waspie</span><span class="f3 push-content">:XDDDDDDD</span><span class="push-ipdatetime"> 09/29 21:34
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Mafty</span><span class="f3 push-content">:有笑有推XD</span><span class="push-ipdatetime"> 09/29 21:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">circlebear</span><span class="f3 push-content">:只能推了</span><span class="push-ipdatetime"> 09/29 21:53
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">babaluu</span><span class="f3 push-content">:靠北！哈哈哈</span><span class="push-ipdatetime"> 09/29 21:54
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">malaimo</span><span class="f3 push-content">:XD</span><span class="push-ipdatetime"> 09/29 22:03
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">watery725</span><span class="f3 push-content">:你這是置入行銷吼 被我發現了</span><span class="push-ipdatetime"> 09/29 22:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">specialp0130</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/29 23:04
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">finalreal</span><span class="f3 push-content">:我看到推文才撲哧了</span><span class="push-ipdatetime"> 09/29 23:16
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">abc9gad</span><span class="f3 push-content">:大推......</span><span class="push-ipdatetime"> 09/29 23:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tp950016</span><span class="f3 push-content">:XDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 00:04
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Tenging</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 00:06
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">tadpole0731</span><span class="f3 push-content">:講得頭頭是道啊</span><span class="push-ipdatetime"> 09/30 00:19
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">seraph01</span><span class="f3 push-content">:世界知名的大企業啊!</span><span class="push-ipdatetime"> 09/30 00:36
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Akichann</span><span class="f3 push-content">:什麼鬼XDDDDD</span><span class="push-ipdatetime"> 09/30 01:11
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">osk2</span><span class="f3 push-content">:後勁超強XDDDD</span><span class="push-ipdatetime"> 09/30 01:16
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">s908322001</span><span class="f3 push-content">:後勁好強</span><span class="push-ipdatetime"> 09/30 01:21
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">AAPL</span><span class="f3 push-content">:XDDD</span><span class="push-ipdatetime"> 09/30 01:28
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Tenging</span><span class="f3 push-content">:全球百大</span><span class="push-ipdatetime"> 09/30 02:27
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">jxxk</span><span class="f3 push-content">:XDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 02:42
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mayimmmmmmm</span><span class="f3 push-content">:害我認真了..</span><span class="push-ipdatetime"> 09/30 04:25
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">mengmine</span><span class="f3 push-content">:XDDDDDDD 耶？也對耶！</span><span class="push-ipdatetime"> 09/30 07:59
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ru486</span><span class="f3 push-content">:XDDDD</span><span class="push-ipdatetime"> 09/30 08:26
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">faye8626</span><span class="f3 push-content">:XDDDDD</span><span class="push-ipdatetime"> 09/30 11:24
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">carzy</span><span class="f3 push-content">:看完後英文不好的我也得到自信了XDD</span><span class="push-ipdatetime"> 09/30 12:04
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">Spade</span><span class="f3 push-content">:害我認真看</span><span class="push-ipdatetime"> 09/30 14:06
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">wml92155</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 14:38
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">ChaiSin</span><span class="f3 push-content">:害我以為走錯版XDDDD</span><span class="push-ipdatetime"> 09/30 15:44
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Deesu</span><span class="f3 push-content">:害我差點燒了所有英文書</span><span class="push-ipdatetime"> 09/30 16:16
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">particular</span><span class="f3 push-content">:算你有才</span><span class="push-ipdatetime"> 09/30 17:12
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">elwyn</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 17:55
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Imset</span><span class="f3 push-content">:真的很有道理阿~</span><span class="push-ipdatetime"> 09/30 19:02
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">pomelo168168</span><span class="f3 push-content">:朝聖XD</span><span class="push-ipdatetime"> 09/30 21:08
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">persuitof</span><span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 21:37
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">barry750128</span><span class="f3 push-content">:他也沒說謊阿 XDDDDDDDDDDD</span><span class="push-ipdatetime"> 09/30 23:08
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">buny36</span><span class="f3 push-content">:我認真了，哈哈哈哈</span><span class="push-ipdatetime"> 10/03 14:38
# </span></div></div>
# <div data-longpollurl="/v1/longpoll?id=7f10067dcefd7e8a394f2c935ea8e3a52bf57cf8" data-offset="23538" data-pollurl="/poll/joke/M.1380444935.A.7A8.html?cacheKey=2148-885284401&amp;offset=23538&amp;offset-sig=06856644d7bc5c3c23129685bb557066c8b09c9f" id="article-polling"></div>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"8057dfe12c7a14d0","version":"2023.8.0","r":1,"b":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","si":100}' defer="" integrity="sha512-bjgnUKX4azu3dLTVtie9u6TKqgx29RBwfj3QXYt5EKfWM/9hPSAI/4qcV5NACjwAo8UtTeWefx6Zq5PHcMm7Tg==" src="https://static.cloudflareinsights.com/beacon.min.js/v8b253dfea2ab4077af8c6f58422dfbfd1689876627854"></script>
# </body>
# </html>

# %% [markdown]
# #### 取得文章標題及其他資訊

# %%
article_meta_values = soup.select(".article-meta-value")
article_meta_values
# Out:
# [<span class="article-meta-value">lihsien (希洛)</span>,
#  <span class="article-meta-value">joke</span>,
#  <span class="article-meta-value">Fw: [問卦] 英文真的重要嗎</span>,
#  <span class="article-meta-value">Sun Sep 29 16:55:33 2013</span>]

# %%
# 分別取出作者、看板、標題、時間
post_author = article_meta_values[0].text
post_category = article_meta_values[1].text
post_title = article_meta_values[2].text
post_time = article_meta_values[3].text

print(f"作者：{post_author}\n",
      f"看板：{post_category}\n",
      f"標題：{post_title}\n",
      f"時間：{post_time}\n")
# Out:
# 作者：lihsien (希洛)
#  看板：joke
#  標題：Fw: [問卦] 英文真的重要嗎
#  時間：Sun Sep 29 16:55:33 2013

# %% [markdown]
# #### 取得留言列表

# %%
# 找出所有 class 為 "f3 push-content" 的 tag
push_contents = soup.select(".f3.push-content") # 記得要把空格換成點
push_contents
# Out:
# [<span class="f3 push-content">:XDDDDDDDDDD</span>,
#  <span class="f3 push-content">:倒數第二句??</span>,
#  <span class="f3 push-content">:ㄜ..</span>,
#  <span class="f3 push-content">:美商英文能力不好怎麼進的....</span>,
#  <span class="f3 push-content">:能夠當下判斷出綠皮馬鈴薯才重要</span>,
#  <span class="f3 push-content">:XDDDDD</span>,
#  <span class="f3 push-content">:有好笑到</span>,
#  <span class="f3 push-content">:麥當勞打工......</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:........麥當勞 靠</span>,
#  <span class="f3 push-content">:.........</span>,
#  <span class="f3 push-content">:。。。。。。</span>,
#  <span class="f3 push-content">:這篇很瓦風</span>,
#  <span class="f3 push-content">:..................</span>,
#  <span class="f3 push-content">:會覺得某件事不重要都是沒辦法把那件事作好才安慰自己</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:就是有這種文，八卦板才有活力</span>,
#  <span class="f3 push-content">:今天滿是這種靠北文章XDDDDD</span>,
#  <span class="f3 push-content">:哈哈</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:靠杯喔害我認真了XD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:靠北 我也認真看完了</span>,
#  <span class="f3 push-content">:這篇超讚的啦XDDDDD</span>,
#  <span class="f3 push-content">:靠杯喔</span>,
#  <span class="f3 push-content">:靠杯，我竟然認真了 XD</span>,
#  <span class="f3 push-content">:認真文推</span>,
#  <span class="f3 push-content">:靠北 XDDDDDDDDD</span>,
#  <span class="f3 push-content">:在法商做簡報還不是不用法文就可以過          家樂福</span>,
#  <span class="f3 push-content">:反串文 puchline在麥當勞</span>,
#  <span class="f3 push-content">:這文廢到好笑</span>,
#  <span class="f3 push-content">:麥當勞打工還要簡報喔</span>,
#  <span class="f3 push-content">:XDDDDD沒看推文我還沒發現 倒數第二行</span>,
#  <span class="f3 push-content">:XDDDDD</span>,
#  <span class="f3 push-content">:靠杯  看完了XD</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:XDDDDDD</span>,
#  <span class="f3 push-content">:哈哈哈 笑死我了XD</span>,
#  <span class="f3 push-content">:ㄏㄏ</span>,
#  <span class="f3 push-content">:你到底要跟誰簡報?</span>,
#  <span class="f3 push-content">:全家是日商？</span>,
#  <span class="f3 push-content">:Joke文</span>,
#  <span class="f3 push-content">:有靠杯到XDXDDDDDDD</span>,
#  <span class="f3 push-content">:幹你贏了XDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:都是為你 都是為你 麥當勞都是為你</span>,
#  <span class="f3 push-content">:XDDDDDDDDD</span>,
#  <span class="f3 push-content">:靠霸 XDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:靠杯 害我認真XDDD</span>,
#  <span class="f3 push-content">:你太有才了！</span>,
#  <span class="f3 push-content">:你贏了</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDD</span>,
#  <span class="f3 push-content">:炸個薯條還得作簡報XDDDD</span>,
#  <span class="f3 push-content">:..............................................</span>,
#  <span class="f3 push-content">:好強大的文章 XD</span>,
#  <span class="f3 push-content">:XDDDDDDDDD</span>,
#  <span class="f3 push-content">:你淫惹</span>,
#  <span class="f3 push-content">:XXXXXXXXXXXXXXXXXXXXXXXXXDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:有笑有推</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:BIG MAC !  BIG MAC !</span>,
#  <span class="f3 push-content">:英文是你要搶老外的錢的重要基礎 就好像你要搶日本人錢就需</span>,
#  <span class="f3 push-content">:跟親鏡子有得拚</span>,
#  <span class="f3 push-content">:ψ-(._. )&gt;</span>,
#  <span class="f3 push-content">:靠腰 後勁好強 XDDDDDDDDDD</span>,
#  <span class="f3 push-content">:己霸婚</span>,
#  <span class="f3 push-content">:有笑有推XDDD</span>,
#  <span class="f3 push-content">:要日文一樣....[用不到?那是你不會用]</span>,
#  <span class="f3 push-content">:我笑了。</span>,
#  <span class="f3 push-content">:XDD</span>,
#  <span class="f3 push-content">:XDD</span>,
#  <span class="f3 push-content">:浪費我時間</span>,
#  <span class="f3 push-content">:幹，後勁好強，幾霸婚</span>,
#  <span class="f3 push-content">:好煩XDDDDD</span>,
#  <span class="f3 push-content">:有笑有推</span>,
#  <span class="f3 push-content">:XDD</span>,
#  <span class="f3 push-content">:靠杯 麥當勞 XDD</span>,
#  <span class="f3 push-content">:靠XDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:GJ !</span>,
#  <span class="f3 push-content">:.....XD</span>,
#  <span class="f3 push-content">:噗哧!說得很有道理!</span>,
#  <span class="f3 push-content">:麥當勞工讀生要對客戶對老闆做簡報嗎?又是個滿口謊言的騜.</span>,
#  <span class="f3 push-content">:XDDDDDDDDDD</span>,
#  <span class="f3 push-content">:有笑有推</span>,
#  <span class="f3 push-content">:也太好笑XDD</span>,
#  <span class="f3 push-content">:大推，八卦版需要你啊！</span>,
#  <span class="f3 push-content">:好笑，但是舉例很爛...</span>,
#  <span class="f3 push-content">:殺小!!!</span>,
#  <span class="f3 push-content">:向客人解說每個餐的內容 就是簡報啊</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:用餐時間緊迫不能說太久 就是簡報</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:專業</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:靠杯 XDDD</span>,
#  <span class="f3 push-content">:後勁好強的回馬槍!</span>,
#  <span class="f3 push-content">:XDD</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDDDD</span>,
#  <span class="f3 push-content">:你贏了</span>,
#  <span class="f3 push-content">:幹  我笑了</span>,
#  <span class="f3 push-content">:XDDD</span>,
#  <span class="f3 push-content">:請容我簡報一下今天的新套餐。</span>,
#  <span class="f3 push-content">:我笑了</span>,
#  <span class="f3 push-content">:哈哈</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDD  你贏了</span>,
#  <span class="f3 push-content">:所以你的專業能力是啥?</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:用英文點餐的老外你會跟他說 阿鬼 你還是說中文嗎？</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:XDDDDDD</span>,
#  <span class="f3 push-content">:XD 害我晚餐想吃麥當勞了</span>,
#  <span class="f3 push-content">:優質廢文!!!</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDD你讓我笑了!!!!</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:xdddddddddd</span>,
#  <span class="f3 push-content">:推</span>,
#  <span class="f3 push-content">:You, waste my time!</span>,
#  <span class="f3 push-content">:疑  好像沒錯XD</span>,
#  <span class="f3 push-content">:今天晚餐就來兩個小麥克好了</span>,
#  <span class="f3 push-content">:繼上一篇親親要閉眼後 又一個溫馨文 XD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:有笑有推</span>,
#  <span class="f3 push-content">:笑死我了XDDDDDD</span>,
#  <span class="f3 push-content">:靠北已笑</span>,
#  <span class="f3 push-content">:俺服了~把這篇文印下來去跟老闆要求加薪吧~XDD</span>,
#  <span class="f3 push-content">:xDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:肯德基的全部站出來！</span>,
#  <span class="f3 push-content">:好文</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:有笑有推</span>,
#  <span class="f3 push-content">:倒數第二句讓我笑翻！</span>,
#  <span class="f3 push-content">:有人想轉joke版嗎?XDDDDDDDDD</span>,
#  <span class="f3 push-content">:鋪疵</span>,
#  <span class="f3 push-content">:認真的嗎</span>,
#  <span class="f3 push-content">:家樂福:</span>,
#  <span class="f3 push-content">:-.-</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:大笑</span>,
#  <span class="f3 push-content">:好煩喔XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:美商                                             7-11</span>,
#  <span class="f3 push-content">:借轉joke</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:.........</span>,
#  <span class="f3 push-content">:XDDDDDDDD</span>,
#  <span class="f3 push-content">:再推一次</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:再推</span>,
#  <span class="f3 push-content">:XDDDDDDD</span>,
#  <span class="f3 push-content">:這應該害英文不好的人白高興一下 XD</span>,
#  <span class="f3 push-content">:再推~XD</span>,
#  <span class="f3 push-content">:推XDD</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:還有人法文不好卻在最大法商家樂福上班哦 XD</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:真中肯</span>,
#  <span class="f3 push-content">:幹   害我白開心了</span>,
#  <span class="f3 push-content">:朝聖</span>,
#  <span class="f3 push-content">:XD 法商家樂福</span>,
#  <span class="f3 push-content">:靠XDDDDDDDDD</span>,
#  <span class="f3 push-content">:又是個 逼妹逼妹 !!!</span>,
#  <span class="f3 push-content">:...</span>,
#  <span class="f3 push-content">:XDDDDD</span>,
#  <span class="f3 push-content">:前面看的覺得好屌，後來想想我在就可版就想說結局...</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:過來人的經驗啊!(筆記</span>,
#  <span class="f3 push-content">:美商賀寶芙之類的也行啊XD</span>,
#  <span class="f3 push-content">:XDDDDD</span>,
#  <span class="f3 push-content">:XDD</span>,
#  <span class="f3 push-content">:害我認真XDDDDD</span>,
#  <span class="f3 push-content">: ＮＯＴ　ＢＡＤ！</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:有笑有推~</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:XDDDDDDD</span>,
#  <span class="f3 push-content">:有笑有推XD</span>,
#  <span class="f3 push-content">:只能推了</span>,
#  <span class="f3 push-content">:靠北！哈哈哈</span>,
#  <span class="f3 push-content">:XD</span>,
#  <span class="f3 push-content">:你這是置入行銷吼 被我發現了</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:我看到推文才撲哧了</span>,
#  <span class="f3 push-content">:大推......</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:講得頭頭是道啊</span>,
#  <span class="f3 push-content">:世界知名的大企業啊!</span>,
#  <span class="f3 push-content">:什麼鬼XDDDDD</span>,
#  <span class="f3 push-content">:後勁超強XDDDD</span>,
#  <span class="f3 push-content">:後勁好強</span>,
#  <span class="f3 push-content">:XDDD</span>,
#  <span class="f3 push-content">:全球百大</span>,
#  <span class="f3 push-content">:XDDDDDDDDDD</span>,
#  <span class="f3 push-content">:害我認真了..</span>,
#  <span class="f3 push-content">:XDDDDDDD 耶？也對耶！</span>,
#  <span class="f3 push-content">:XDDDD</span>,
#  <span class="f3 push-content">:XDDDDD</span>,
#  <span class="f3 push-content">:看完後英文不好的我也得到自信了XDD</span>,
#  <span class="f3 push-content">:害我認真看</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:害我以為走錯版XDDDD</span>,
#  <span class="f3 push-content">:害我差點燒了所有英文書</span>,
#  <span class="f3 push-content">:算你有才</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:真的很有道理阿~</span>,
#  <span class="f3 push-content">:朝聖XD</span>,
#  <span class="f3 push-content">:XDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:他也沒說謊阿 XDDDDDDDDDDD</span>,
#  <span class="f3 push-content">:我認真了，哈哈哈哈</span>]

# %% [markdown]
# #### 進階：按照結構找出留言的各種資訊
# 在前面的方式中，我們會發現若直接用`f3 push-content`去取得內容，只會留下留言的內容，但是無法取得留言的其他資訊(例如：留言者、留言時間)。
# 因此這邊可以對過程進行調整，先找出每一則推文內容的上一層的物件，再取得它底下的各種資訊

# %%
# 找出所有 class 為 "push" 的 tag
pushes = soup.select(".push")
pushes[0] # 先看看第一個推文的結構
# Out:
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">cephalitis</span><span class="f3 push-content">:XDDDDDDDDDD</span><span class="push-ipdatetime"> 09/29 16:27
# </span></div>

# %%
# 以pushes[0]為例
# 分別找出 "hl push-tag", "f3 hl push-userid", "f3 push-content", "f3 push-ipdatetime" 的 tag
push_tag = pushes[0].select_one(".hl.push-tag").text
push_userid = pushes[0].select_one(".f3.hl.push-userid").text
push_content = pushes[0].select_one(".f3.push-content").text
push_ipdatetime = pushes[0].select_one(".push-ipdatetime").text

print(f"推文類型：{push_tag}\n",
      f"推文作者：{push_userid}\n",
      f"推文內容：{push_content}\n",
      f"推文時間：{push_ipdatetime}\n")
# Out:
# 推文類型：推
#  推文作者：cephalitis
#  推文內容：:XDDDDDDDDDD
#  推文時間： 09/29 16:27

# %% [markdown]
# ## 搜尋關鍵字取得文章列表

# %% [markdown]
# ### 從搜尋頁面取得內容

# %%
import requests
from bs4 import BeautifulSoup

BOARD = "joke" # 欲搜尋的看板
KEYWORD = "地獄" # 欲搜尋的關鍵字
SEARCH_URL = f"https://www.ptt.cc/bbs/{BOARD}/search?page=1&q={KEYWORD}"
response = requests.get(SEARCH_URL)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>地獄 - joke - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/joke/index.html"><span class="board-label">看板 </span>joke</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn" href="/bbs/joke/index.html">‹ 看板</a>
# <a class="btn" href="/man/joke/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/joke/search?page=91&amp;q=%E5%9C%B0%E7%8D%84">最舊</a>
# <a class="btn wide" href="/bbs/joke/search?page=2&amp;q=%E5%9C%B0%E7%8D%84">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/joke/search?page=1&amp;q=%E5%9C%B0%E7%8D%84">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value="地獄"/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">19</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1694424295.A.4F7.html">[地獄] 時光膠囊</a>
# </div>
# <div class="meta">
# <div class="author">atliberty</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E6%99%82%E5%85%89%E8%86%A0%E5%9B%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Aatliberty">搜尋看板內 atliberty 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/11</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">78</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1694409851.A.6C3.html">[地獄] 牧師死後</a>
# </div>
# <div class="meta">
# <div class="author">belleaya</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E7%89%A7%E5%B8%AB%E6%AD%BB%E5%BE%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Abelleaya">搜尋看板內 belleaya 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/11</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">48</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1694238818.A.7B6.html">[地獄] 迴力鏢打到自己囉</a>
# </div>
# <div class="meta">
# <div class="author">sherlockan</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E8%BF%B4%E5%8A%9B%E9%8F%A2%E6%89%93%E5%88%B0%E8%87%AA%E5%B7%B1%E5%9B%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Asherlockan">搜尋看板內 sherlockan 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1693932594.A.B11.html">[地獄] 哪個展覽活動待人冷淡</a>
# </div>
# <div class="meta">
# <div class="author">Hanedas</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E5%93%AA%E5%80%8B%E5%B1%95%E8%A6%BD%E6%B4%BB%E5%8B%95%E5%BE%85%E4%BA%BA%E5%86%B7%E6%B7%A1">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3AHanedas">搜尋看板內 Hanedas 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1693316842.A.0C1.html">[地獄] 孝順的阿明</a>
# </div>
# <div class="meta">
# <div class="author">xx49874039</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E5%AD%9D%E9%A0%86%E7%9A%84%E9%98%BF%E6%98%8E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Axx49874039">搜尋看板內 xx49874039 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/29</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1693019558.A.515.html">[地獄] 鳳梨加油</a>
# </div>
# <div class="meta">
# <div class="author">LeeAnAn</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E9%B3%B3%E6%A2%A8%E5%8A%A0%E6%B2%B9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3ALeeAnAn">搜尋看板內 LeeAnAn 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/26</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1692825520.A.2CC.html">[地獄] 華格納大廚死了</a>
# </div>
# <div class="meta">
# <div class="author">chibmw</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E8%8F%AF%E6%A0%BC%E7%B4%8D%E5%A4%A7%E5%BB%9A%E6%AD%BB%E4%BA%86">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Achibmw">搜尋看板內 chibmw 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1692601045.A.590.html">[地獄] 為什麼大家都不禮讓行人</a>
# </div>
# <div class="meta">
# <div class="author">Hanbor</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E7%82%BA%E4%BB%80%E9%BA%BC%E5%A4%A7%E5%AE%B6%E9%83%BD%E4%B8%8D%E7%A6%AE%E8%AE%93%E8%A1%8C%E4%BA%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3AHanbor">搜尋看板內 Hanbor 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/21</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">24</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1692336705.A.776.html">[地獄]吉娃娃被輾</a>
# </div>
# <div class="meta">
# <div class="author">hchsu</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D%E5%90%89%E5%A8%83%E5%A8%83%E8%A2%AB%E8%BC%BE">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Ahchsu">搜尋看板內 hchsu 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/18</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1691997590.A.4B9.html">[地獄] 買星巴克前面排的是牙套大舌頭妹</a>
# </div>
# <div class="meta">
# <div class="author">LeeAnAn</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E8%B2%B7%E6%98%9F%E5%B7%B4%E5%85%8B%E5%89%8D%E9%9D%A2%E6%8E%92%E7%9A%84%E6%98%AF%E7%89%99%E5%A5%97%E5%A4%A7%E8%88%8C%E9%A0%AD%E5%A6%B9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3ALeeAnAn">搜尋看板內 LeeAnAn 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1691674876.A.0F1.html">[地獄] 諾蘭 電影不用特效</a>
# </div>
# <div class="meta">
# <div class="author">songgood</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E8%AB%BE%E8%98%AD+%E9%9B%BB%E5%BD%B1%E4%B8%8D%E7%94%A8%E7%89%B9%E6%95%88">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Asonggood">搜尋看板內 songgood 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/10</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1691611644.A.962.html">[地獄] youtube你確定不是故意的嗎？</a>
# </div>
# <div class="meta">
# <div class="author">ap88994433</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+youtube%E4%BD%A0%E7%A2%BA%E5%AE%9A%E4%B8%8D%E6%98%AF%E6%95%85%E6%84%8F%E7%9A%84%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Aap88994433">搜尋看板內 ap88994433 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/10</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1691482984.A.488.html">[地獄] 怎麼避免AI算圖手指會扭曲</a>
# </div>
# <div class="meta">
# <div class="author">EYECTV</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E6%80%8E%E9%BA%BC%E9%81%BF%E5%85%8DAI%E7%AE%97%E5%9C%96%E6%89%8B%E6%8C%87%E6%9C%83%E6%89%AD%E6%9B%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3AEYECTV">搜尋看板內 EYECTV 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1691475733.A.D6E.html">[地獄] 愛馬仕父親節貼心贈禮</a>
# </div>
# <div class="meta">
# <div class="author">csfaust</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E6%84%9B%E9%A6%AC%E4%BB%95%E7%88%B6%E8%A6%AA%E7%AF%80%E8%B2%BC%E5%BF%83%E8%B4%88%E7%A6%AE">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Acsfaust">搜尋看板內 csfaust 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1691284934.A.C1F.html">[地獄] 小奶狗</a>
# </div>
# <div class="meta">
# <div class="author">calmlycindy</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E5%B0%8F%E5%A5%B6%E7%8B%97">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Acalmlycindy">搜尋看板內 calmlycindy 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1690785717.A.17B.html">[地獄] 湖中女神</a>
# </div>
# <div class="meta">
# <div class="author">scores</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E6%B9%96%E4%B8%AD%E5%A5%B3%E7%A5%9E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Ascores">搜尋看板內 scores 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/31</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1690779747.A.C31.html">[地獄] 憂鬱症</a>
# </div>
# <div class="meta">
# <div class="author">bromelia0</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E6%86%82%E9%AC%B1%E7%97%87">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Abromelia0">搜尋看板內 bromelia0 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/31</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1690670916.A.472.html">[地獄] Bronny James 訓練反應都玩什麼？</a>
# </div>
# <div class="meta">
# <div class="author">asn789451</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+Bronny+James+%E8%A8%93%E7%B7%B4%E5%8F%8D%E6%87%89%E9%83%BD%E7%8E%A9%E4%BB%80%E9%BA%BC%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Aasn789451">搜尋看板內 asn789451 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/30</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1690413062.A.ADD.html">[地獄] 一個笑話</a>
# </div>
# <div class="meta">
# <div class="author">kinda83</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E4%B8%80%E5%80%8B%E7%AC%91%E8%A9%B1">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Akinda83">搜尋看板內 kinda83 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/27</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/joke/M.1690357589.A.3D9.html">[地獄] 嬰兒空氣吸k</a>
# </div>
# <div class="meta">
# <div class="author">songgood</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E5%AC%B0%E5%85%92%E7%A9%BA%E6%B0%A3%E5%90%B8k">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Asonggood">搜尋看板內 songgood 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/26</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"8057e0509fee20c5","version":"2023.8.0","r":1,"b":1,"token":"515615eb5fab4c9b91a11e9bf529e6cf","si":100}' defer="" integrity="sha512-bjgnUKX4azu3dLTVtie9u6TKqgx29RBwfj3QXYt5EKfWM/9hPSAI/4qcV5NACjwAo8UtTeWefx6Zq5PHcMm7Tg==" src="https://static.cloudflareinsights.com/beacon.min.js/v8b253dfea2ab4077af8c6f58422dfbfd1689876627854"></script>
# </body>
# </html>

# %% [markdown]
# ### 取得文章列表

# %%
# 找出每一篇貼文的結果
posts = soup.select("div.r-ent")
posts[0] # 先看看第一篇貼文的結構
# Out:
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">19</span></div>
# <div class="title">
# <a href="/bbs/joke/M.1694424295.A.4F7.html">[地獄] 時光膠囊</a>
# </div>
# <div class="meta">
# <div class="author">atliberty</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/joke/search?q=thread%3A%5B%E5%9C%B0%E7%8D%84%5D+%E6%99%82%E5%85%89%E8%86%A0%E5%9B%8A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/joke/search?q=author%3Aatliberty">搜尋看板內 atliberty 的文章</a></div>
# </div>
# </div>
# <div class="date"> 9/11</div>
# <div class="mark"></div>
# </div>
# </div>

# %%
# 以posts[0]為例，找出連結、標題、作者、推文數
post_url = posts[0].find("div", "title").a.attrs["href"]
post_title = posts[0].find("div", "title").text.strip()
post_author = posts[0].find("div", "author").text.strip()
post_push = posts[0].find("div", "nrec").text.strip()
print(f"貼文連結：{post_url}\n")
print(f"貼文標題：{post_title}\n")
print(f"貼文作者：{post_author}\n")
print(f"貼文推文數：{post_push}\n")
# Out:
# 貼文連結：/bbs/joke/M.1694424295.A.4F7.html
#
# 貼文標題：[地獄] 時光膠囊
#
# 貼文作者：atliberty
#
# 貼文推文數：19

# %%
# 將這個頁面的所有貼文資訊加入到一個list中
post_list = []
for post in posts:
    post_url = post.find("div", "title").a.attrs["href"]
    post_title = post.find("div", "title").text.strip()
    post_author = post.find("div", "author").text.strip()
    post_push = post.find("div", "nrec").text.strip()
    post_list.append({
        "url": post_url,
        "title": post_title,
        "author": post_author,
        "push": post_push
    })
post_list[:3] # 查看前三篇貼文的資訊
# Out:
# [{'url': '/bbs/joke/M.1694424295.A.4F7.html',
#   'title': '[地獄] 時光膠囊',
#   'author': 'atliberty',
#   'push': '19'},
#  {'url': '/bbs/joke/M.1694409851.A.6C3.html',
#   'title': '[地獄] 牧師死後',
#   'author': 'belleaya',
#   'push': '78'},
#  {'url': '/bbs/joke/M.1694238818.A.7B6.html',
#   'title': '[地獄] 迴力鏢打到自己囉',
#   'author': 'sherlockan',
#   'push': '48'}]

# %% [markdown]
# ### 取得所有文章列表(跨頁)

# %%
post_list = [] # 建立一個空的list來存放所有文章資訊
page = 1 # 從第一頁開始
while True:
    full_url = f"https://www.ptt.cc/bbs/{BOARD}/search?page={page}&q={KEYWORD}"
    response = requests.get(full_url, cookies={"over18": "1"}) # 設定cookie通過滿18歲的檢查
    print(f"正在處理第 {page} 頁，目前累積 {len(post_list)} 篇文章", end="\r")
    if response.status_code != 200:
        break
    else:
        soup = BeautifulSoup(response.text, "lxml")
        posts = soup.select("div.r-ent")
        for post in posts:
            post_url = post.find("div", "title").a.attrs["href"]
            post_title = post.find("div", "title").text.strip()
            post_author = post.find("div", "author").text.strip()
            post_push = post.find("div", "nrec").text.strip()
            post_list.append({
                "url": post_url,
                "title": post_title,
                "author": post_author,
                "push": post_push
            })
        page += 1
# Out:
# 正在處理第 92 頁，目前累積 1812 篇文章

# %%
# 將資料轉換成dataframe
import pandas as pd
df = pd.DataFrame(post_list, columns=["title", "author", "push", "url"])
df
# Out:
#                         title      author push  \
# 0                   [地獄] 時光膠囊   atliberty   19
# 1                   [地獄] 牧師死後    belleaya   78
# 2               [地獄] 迴力鏢打到自己囉  sherlockan   48
# 3             [地獄] 哪個展覽活動待人冷淡     Hanedas    3
# 4                  [地獄] 孝順的阿明  xx49874039    4
# ...                       ...         ...  ...
# 1807       Re: [耍冷] 吳鳳死了下地獄！？     aaagang   23
# 1808           [耍冷] 吳鳳死了下地獄！？      SUZIKU    1
# 1809         [笑話] 你要上天堂還是下地獄?     ijn123g    1
# 1810  [翻譯] Oatmeal：印表機是地獄的使者！  SetsunaLeo    8
# 1811           [耍冷] 哪家業者該下地獄?     q910044
#
#                                     url
# 0     /bbs/joke/M.1694424295.A.4F7.html
# 1     /bbs/joke/M.1694409851.A.6C3.html
# 2     /bbs/joke/M.1694238818.A.7B6.html
# 3     /bbs/joke/M.1693932594.A.B11.html
# 4     /bbs/joke/M.1693316842.A.0C1.html
# ...                                 ...
# 1807  /bbs/joke/M.1383835628.A.639.html
# 1808  /bbs/joke/M.1383832975.A.2F0.html
# 1809  /bbs/joke/M.1382606366.A.5C9.html
# 1810  /bbs/joke/M.1379386388.A.D6E.html
# 1811  /bbs/joke/M.1374267177.A.437.html
#
# [1812 rows x 4 columns]

# %%
# 儲存成csv檔
df.to_csv("ptt_joke.csv", index=False, encoding="utf-8-sig")

# %% [markdown]
# ## 從列表取得每一篇文章的內容與留言

# %% [markdown]
# ### 還原網址

# %%
import pandas as pd
df = pd.read_csv("ptt_joke.csv")
df["url"] = df["url"].apply(lambda x: "https://www.ptt.cc" + x)
df
# Out:
#                         title      author push  \
# 0                   [地獄] 時光膠囊   atliberty   19
# 1                   [地獄] 牧師死後    belleaya   78
# 2               [地獄] 迴力鏢打到自己囉  sherlockan   48
# 3             [地獄] 哪個展覽活動待人冷淡     Hanedas    3
# 4                  [地獄] 孝順的阿明  xx49874039    4
# ...                       ...         ...  ...
# 1807       Re: [耍冷] 吳鳳死了下地獄！？     aaagang   23
# 1808           [耍冷] 吳鳳死了下地獄！？      SUZIKU    1
# 1809         [笑話] 你要上天堂還是下地獄?     ijn123g    1
# 1810  [翻譯] Oatmeal：印表機是地獄的使者！  SetsunaLeo    8
# 1811           [耍冷] 哪家業者該下地獄?     q910044  NaN
#
#                                                     url
# 0     https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# 1     https://www.ptt.cc/bbs/joke/M.1694409851.A.6C3...
# 2     https://www.ptt.cc/bbs/joke/M.1694238818.A.7B6...
# 3     https://www.ptt.cc/bbs/joke/M.1693932594.A.B11...
# 4     https://www.ptt.cc/bbs/joke/M.1693316842.A.0C1...
# ...                                                 ...
# 1807  https://www.ptt.cc/bbs/joke/M.1383835628.A.639...
# 1808  https://www.ptt.cc/bbs/joke/M.1383832975.A.2F0...
# 1809  https://www.ptt.cc/bbs/joke/M.1382606366.A.5C9...
# 1810  https://www.ptt.cc/bbs/joke/M.1379386388.A.D6E...
# 1811  https://www.ptt.cc/bbs/joke/M.1374267177.A.437...
#
# [1812 rows x 4 columns]

# %% [markdown]
# ### 取得回應結果

# %%
df = df[:20] # 取其中20筆作為示範，若要取得所有資料，請將這行拿掉
df
# Out:
#                           title       author push  \
# 0                     [地獄] 時光膠囊    atliberty   19
# 1                     [地獄] 牧師死後     belleaya   78
# 2                 [地獄] 迴力鏢打到自己囉   sherlockan   48
# 3               [地獄] 哪個展覽活動待人冷淡      Hanedas    3
# 4                    [地獄] 孝順的阿明   xx49874039    4
# 5                     [地獄] 鳳梨加油      LeeAnAn    7
# 6                  [地獄] 華格納大廚死了       chibmw    2
# 7              [地獄] 為什麼大家都不禮讓行人       Hanbor  NaN
# 8                     [地獄]吉娃娃被輾        hchsu   24
# 9          [地獄] 買星巴克前面排的是牙套大舌頭妹      LeeAnAn    4
# 10               [地獄] 諾蘭 電影不用特效     songgood  NaN
# 11       [地獄] youtube你確定不是故意的嗎？   ap88994433  NaN
# 12           [地獄] 怎麼避免AI算圖手指會扭曲       EYECTV    8
# 13              [地獄] 愛馬仕父親節貼心贈禮      csfaust    9
# 14                     [地獄] 小奶狗  calmlycindy  NaN
# 15                    [地獄] 湖中女神       scores    2
# 16                     [地獄] 憂鬱症    bromelia0  NaN
# 17  [地獄] Bronny James 訓練反應都玩什麼？    asn789451  NaN
# 18                    [地獄] 一個笑話      kinda83    2
# 19                  [地獄] 嬰兒空氣吸k     songgood  NaN
#
#                                                   url
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# 1   https://www.ptt.cc/bbs/joke/M.1694409851.A.6C3...
# 2   https://www.ptt.cc/bbs/joke/M.1694238818.A.7B6...
# 3   https://www.ptt.cc/bbs/joke/M.1693932594.A.B11...
# 4   https://www.ptt.cc/bbs/joke/M.1693316842.A.0C1...
# 5   https://www.ptt.cc/bbs/joke/M.1693019558.A.515...
# 6   https://www.ptt.cc/bbs/joke/M.1692825520.A.2CC...
# 7   https://www.ptt.cc/bbs/joke/M.1692601045.A.590...
# 8   https://www.ptt.cc/bbs/joke/M.1692336705.A.776...
# 9   https://www.ptt.cc/bbs/joke/M.1691997590.A.4B9...
# 10  https://www.ptt.cc/bbs/joke/M.1691674876.A.0F1...
# 11  https://www.ptt.cc/bbs/joke/M.1691611644.A.962...
# 12  https://www.ptt.cc/bbs/joke/M.1691482984.A.488...
# 13  https://www.ptt.cc/bbs/joke/M.1691475733.A.D6E...
# 14  https://www.ptt.cc/bbs/joke/M.1691284934.A.C1F...
# 15  https://www.ptt.cc/bbs/joke/M.1690785717.A.17B...
# 16  https://www.ptt.cc/bbs/joke/M.1690779747.A.C31...
# 17  https://www.ptt.cc/bbs/joke/M.1690670916.A.472...
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...
# 19  https://www.ptt.cc/bbs/joke/M.1690357589.A.3D9...

# %%
import pyprind # 顯示進度條
import requests

pbar = pyprind.ProgBar(len(df["url"]), title="正在抓取文章中...") # 設定進度條

def url2response(url):
    response = requests.get(url, cookies={"over18": "1"})
    pbar.update() # 更新進度條
    return response

df["response"] = df["url"].apply(url2response)
# Out:
# Warning: No valid output stream.
# /var/folders/g3/z8dvtvx948nf_788xt5ysznm0000gn/T/ipykernel_3490/2052892789.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["response"] = df["url"].apply(url2response)

# %% [markdown]
# ### 從回應結果提取文章內容

# %%
def get_post_content(response):
    soup = BeautifulSoup(response.text, "lxml")
    # 篩選文章內容
    content = soup.select_one(".bbs-screen.bbs-content")
    # 移除所有span 和div tag 等不必要的tag
    for tag in content.select("span, div, a"):
        tag.decompose()
    return content.text.strip() # 回傳文章內容

df["內文"] = df["response"].apply(get_post_content)
df["內文"]
# Out:
# /var/folders/g3/z8dvtvx948nf_788xt5ysznm0000gn/T/ipykernel_3490/2038142604.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["內文"] = df["response"].apply(get_post_content)
# 0     一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...
# 1     有個牧師過世了\n\n他的靈魂上了天堂\n\n本來期待看到他信奉的上帝\n\n沒想到來迎接他...
# 2                                                    --
# 3                                             客博會\n\n--
# 4     阿明是一個很孝順的孩子\n\n有一天他因為不明原因死了\n\n於是家屬安排驗屍\n\n只見法...
# 5     鳳梨加油，誰沒有過去\n誰沒有假扮檢查官詐騙阿嬤\n誰沒有吸毒，誰沒有販毒\n誰沒有把另一半...
# 6                                            廚爆安涼\n\n--
# 7                                   當人不讓\n\n都變成鬼了\n\n--
# 8     吉娃娃被輾過會變成什麼\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 9     去買星巴克排隊時前面有個戴牙套大舌頭的女孩\n點了一杯「某ㄍㄚˊ拿鐵」\n-----\nSe...
# 10            那核彈..........\n在那爆\n\n--\n\n哎呦 你臉紅了\n\n--
# 11    睡前滑了一下短影片\n\n嗯 又是搬運別人影片的抄襲仔\n\n繼續滑....\n\n嗯？？\...
# 12    現在AI都這麼地獄嗎?\n\n\n力克胡哲圖\n-----\nSent from JPTT ...
# 13    愛馬仕官方line今天發了這張貼心贈禮\n\n\n\n………..\n七月還沒到啊\n\n\n...
# 14                  女：別人的男友都是小奶狗，你只有狗\n男：因為小奶在你那邊\n\n--
# 15    觀眾丟了一杯價值台幣30的飲料\n\n\n      馬上得到演唱會級的無線麥克風 最少上萬...
# 16    為什麼憂鬱症的人都不往好處想?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 17                                            心臟病\n\n--
# 18                     台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--
# 19                 父母又管不到\n保母負責啦\n\n--\n\n哎呦 你臉紅了\n\n--
# Name: 內文, dtype: object

# %% [markdown]
# ### 從回應結果提取留言列表

# %%
def get_comments(response):
    soup = BeautifulSoup(response.text, "lxml")
    pushes = soup.select(".push")
    comment_list = []
    
    for push in pushes:
        # 對每一則留言進行處理，取得相關資訊並加入到comment_list中
        push_tag = push.find("span", "push-tag").text.strip() # 推/噓/→
        push_userid = push.find("span", "push-userid").text.strip() # 推文的使用者id
        push_content = push.find("span", "push-content").text.strip()[2:] # 推文內容
        push_ipdatetime = push.find("span", "push-ipdatetime").text.strip() # 推文的時間
        comment_list.append({
            "推文類型": push_tag,
            "使用者id": push_userid,
            "推文內容": push_content,
            "推文時間": push_ipdatetime,
        })
    
    return comment_list
    
df["留言列表"] = df["response"].apply(get_comments)
df["留言列表"][0] # 查看第一篇文章的留言列表
# Out:
# /var/folders/g3/z8dvtvx948nf_788xt5ysznm0000gn/T/ipykernel_3490/1241693241.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["留言列表"] = df["response"].apply(get_comments)
# [{'推文類型': '推', '使用者id': 'Birdy', '推文內容': '樓下說你是柯粉', '推文時間': '09/11 18:10'},
#  {'推文類型': '→',
#   '使用者id': 'FlynnZhang',
#   '推文內容': '不小心把肛塞劑吃下去 食肛交囊',
#   '推文時間': '09/11 19:07'},
#  {'推文類型': '噓', '使用者id': 'LeeAnAn', '推文內容': '政治滾出joke板', '推文時間': '09/11 19:10'},
#  {'推文類型': '推',
#   '使用者id': 'cerberi',
#   '推文內容': '講笑話 農業部是專業的 何必來這裡欺負業餘玩家',
#   '推文時間': '09/11 19:13'},
#  {'推文類型': '推',
#   '使用者id': 'iKelly',
#   '推文內容': '政治性笑話也是笑話其中一類啊，不然蘇聯系列怎麼辦？',
#   '推文時間': '09/11 21:46'},
#  {'推文類型': '推', '使用者id': 'noname912301', '推文內容': 'www', '推文時間': '09/11 22:05'},
#  {'推文類型': '推', '使用者id': 'if4', '推文內容': '         www', '推文時間': '09/11 22:09'},
#  {'推文類型': '噓',
#   '使用者id': 'markkao456',
#   '推文內容': '重點是不好笑-.-',
#   '推文時間': '09/11 22:56'},
#  {'推文類型': '推',
#   '使用者id': 'kaitokid1214',
#   '推文內容': '齁氣氣氣氣氣氣氣',
#   '推文時間': '09/11 23:01'},
#  {'推文類型': '推',
#   '使用者id': 'fishest',
#   '推文內容': '不是不好笑 是根本笑不出來',
#   '推文時間': '09/11 23:45'},
#  {'推文類型': '→',
#   '使用者id': 'shintz',
#   '推文內容': '夠酸 但是不好笑，政府護航的太難看',
#   '推文時間': '09/12 00:19'},
#  {'推文類型': '推',
#   '使用者id': 'wangf1112',
#   '推文內容': '笑不出來 我的納稅錢...',
#   '推文時間': '09/12 00:26'},
#  {'推文類型': '噓',
#   '使用者id': 'sleepgod0602',
#   '推文內容': '這裡是joke板不是低能板',
#   '推文時間': '09/12 07:18'},
#  {'推文類型': '推',
#   '使用者id': 'Birdy',
#   '推文內容': '照樓上這麼說，相信民進黨的都不能上 joke 版惹',
#   '推文時間': '09/12 09:28'},
#  {'推文類型': '推', '使用者id': 'Yamashiro', '推文內容': '低能仔很氣', '推文時間': '09/12 09:34'},
#  {'推文類型': '推', '使用者id': 'rb510691', '推文內容': '推', '推文時間': '09/12 11:00'},
#  {'推文類型': '推',
#   '使用者id': 'rhythm1217',
#   '推文內容': '埋在土裡的蛋，超濕的',
#   '推文時間': '09/12 11:50'},
#  {'推文類型': '推', '使用者id': 'gzliu', '推文內容': '我愛陳吉仲', '推文時間': '09/12 12:55'},
#  {'推文類型': '推', '使用者id': 'iamnotme', '推文內容': '有加時事梗給推', '推文時間': '09/12 14:05'},
#  {'推文類型': '推', '使用者id': 'kof78225', '推文內容': '笑話在某些樓', '推文時間': '09/12 14:10'},
#  {'推文類型': '推', '使用者id': 'Eijidate', '推文內容': '哈哈哈', '推文時間': '09/12 14:23'},
#  {'推文類型': '推',
#   '使用者id': 'ruiun',
#   '推文內容': '看某些樓的推文，我怕我笑出來會被批鬥',
#   '推文時間': '09/12 16:48'},
#  {'推文類型': '推', '使用者id': 'louisalflame', '推文內容': '有笑有推', '推文時間': '09/12 17:23'},
#  {'推文類型': '推',
#   '使用者id': 'jjalu',
#   '推文內容': '看在有人崩潰的份上給你個推',
#   '推文時間': '09/12 17:25'},
#  {'推文類型': '推', '使用者id': 'hiaries', '推文內容': 'XD', '推文時間': '09/12 17:46'},
#  {'推文類型': '推',
#   '使用者id': 'redmoon9033',
#   '推文內容': '笑點是推文裡的各種崩潰嗎？',
#   '推文時間': '09/12 18:14'},
#  {'推文類型': '推',
#   '使用者id': 'tosh2',
#   '推文內容': '笑點是民進黨支持者的智商',
#   '推文時間': '09/12 18:52'}]

# %% [markdown]
# ### 拆分留言列表並儲存
# + 目前我們的結果中是一整個list，但是這樣的資料是比較難被csv或xlsx進行儲存的，因此我們需要做一些調整。
# + 將留言列表用`explode()`展開，讓每一則留言都是一個row

# %%
# 查看目前的DataFrame的結構
df.head()
# Out:
#              title      author push  \
# 0        [地獄] 時光膠囊   atliberty   19
# 1        [地獄] 牧師死後    belleaya   78
# 2    [地獄] 迴力鏢打到自己囉  sherlockan   48
# 3  [地獄] 哪個展覽活動待人冷淡     Hanedas    3
# 4       [地獄] 孝順的阿明  xx49874039    4
#
#                                                  url          response  \
# 0  https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...  <Response [200]>
# 1  https://www.ptt.cc/bbs/joke/M.1694409851.A.6C3...  <Response [200]>
# 2  https://www.ptt.cc/bbs/joke/M.1694238818.A.7B6...  <Response [200]>
# 3  https://www.ptt.cc/bbs/joke/M.1693932594.A.B11...  <Response [200]>
# 4  https://www.ptt.cc/bbs/joke/M.1693316842.A.0C1...  <Response [200]>
#
#                                                   內文  \
# 0  一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...
# 1  有個牧師過世了\n\n他的靈魂上了天堂\n\n本來期待看到他信奉的上帝\n\n沒想到來迎接他...
# 2                                                 --
# 3                                          客博會\n\n--
# 4  阿明是一個很孝順的孩子\n\n有一天他因為不明原因死了\n\n於是家屬安排驗屍\n\n只見法...
#
#                                                 留言列表
# 0  [{'推文類型': '推', '使用者id': 'Birdy', '推文內容': '樓下說你...
# 1  [{'推文類型': '推', '使用者id': 'chocoboytw', '推文內容': ...
# 2  [{'推文類型': '→', '使用者id': 'Ahhhhaaaa', '推文內容': '...
# 3  [{'推文類型': '推', '使用者id': 'remixk', '推文內容': '肩酸'...
# 4  [{'推文類型': '推', '使用者id': 'if4', '推文內容': '不是「笑死」...

# %%
# 展開留言列表
df_exploded = df.explode("留言列表")
df_exploded.dropna(subset=["留言列表"], inplace=True) # 移除留言列表為空值的資料
df_exploded["推文類型"] = df_exploded["留言列表"].apply(lambda x: x["推文類型"])
df_exploded["使用者id"] = df_exploded["留言列表"].apply(lambda x: x["使用者id"])
df_exploded["推文內容"] = df_exploded["留言列表"].apply(lambda x: x["推文內容"])
df_exploded["推文時間"] = df_exploded["留言列表"].apply(lambda x: x["推文時間"])
df_exploded = df_exploded.drop("留言列表", axis=1) # 移除留言列表欄位
df_exploded
# Out:
#           title     author push  \
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# ..          ...        ...  ...
# 18    [地獄] 一個笑話    kinda83    2
# 18    [地獄] 一個笑話    kinda83    2
# 18    [地獄] 一個笑話    kinda83    2
# 18    [地獄] 一個笑話    kinda83    2
# 19  [地獄] 嬰兒空氣吸k   songgood  NaN
#
#                                                   url          response  \
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...  <Response [200]>
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...  <Response [200]>
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...  <Response [200]>
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...  <Response [200]>
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...  <Response [200]>
# ..                                                ...               ...
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...  <Response [200]>
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...  <Response [200]>
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...  <Response [200]>
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...  <Response [200]>
# 19  https://www.ptt.cc/bbs/joke/M.1690357589.A.3D9...  <Response [200]>
#
#                                                    內文 推文類型       使用者id  \
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    推       Birdy
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    →  FlynnZhang
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    噓     LeeAnAn
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    推     cerberi
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    推      iKelly
# ..                                                ...  ...         ...
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    →    m6990400
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    推       ailio
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    噓    ccchenny
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    推   kcryo0103
# 19               父母又管不到\n保母負責啦\n\n--\n\n哎呦 你臉紅了\n\n--    →    sandiato
#
#                          推文內容         推文時間
# 0                     樓下說你是柯粉  09/11 18:10
# 0             不小心把肛塞劑吃下去 食肛交囊  09/11 19:07
# 0                   政治滾出joke板  09/11 19:10
# 0     講笑話 農業部是專業的 何必來這裡欺負業餘玩家  09/11 19:13
# 0   政治性笑話也是笑話其中一類啊，不然蘇聯系列怎麼辦？  09/11 21:46
# ..                        ...          ...
# 18         放颱風假明明對喜歡上班的社畜更有利。  07/27 07:42
# 18          社畜颱風都是無薪假，上班哪有加班費  07/27 07:50
# 18            自己有放到就很爽 沒放就笑人家  07/27 08:45
# 18               現在都改WFH，沒有假了  07/27 08:53
# 19             我聽到的時候也想說幹怎麼可能  07/26 16:23
#
# [496 rows x 10 columns]

# %%
# 移除不必要的欄位後儲存
df_exploded = df_exploded.drop(["response"], axis=1)
df_exploded.to_csv("ptt_joke_comments.csv", index=False, encoding="utf-8-sig")
df_exploded
# Out:
#           title     author push  \
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# 0     [地獄] 時光膠囊  atliberty   19
# ..          ...        ...  ...
# 18    [地獄] 一個笑話    kinda83    2
# 18    [地獄] 一個笑話    kinda83    2
# 18    [地獄] 一個笑話    kinda83    2
# 18    [地獄] 一個笑話    kinda83    2
# 19  [地獄] 嬰兒空氣吸k   songgood  NaN
#
#                                                   url  \
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# 0   https://www.ptt.cc/bbs/joke/M.1694424295.A.4F7...
# ..                                                ...
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...
# 18  https://www.ptt.cc/bbs/joke/M.1690413062.A.ADD...
# 19  https://www.ptt.cc/bbs/joke/M.1690357589.A.3D9...
#
#                                                    內文 推文類型       使用者id  \
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    推       Birdy
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    →  FlynnZhang
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    噓     LeeAnAn
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    推     cerberi
# 0   一群小朋友相約在校園大樹旁開挖數年前埋下的時光膠囊\n\n打開後，裡面埋著一本獵人漫畫，一罐...    推      iKelly
# ..                                                ...  ...         ...
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    →    m6990400
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    推       ailio
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    噓    ccchenny
# 18                   台南今天放颱風假！\n\n\n\n快進來笑北北基桃！\n\n--    推   kcryo0103
# 19               父母又管不到\n保母負責啦\n\n--\n\n哎呦 你臉紅了\n\n--    →    sandiato
#
#                          推文內容         推文時間
# 0                     樓下說你是柯粉  09/11 18:10
# 0             不小心把肛塞劑吃下去 食肛交囊  09/11 19:07
# 0                   政治滾出joke板  09/11 19:10
# 0     講笑話 農業部是專業的 何必來這裡欺負業餘玩家  09/11 19:13
# 0   政治性笑話也是笑話其中一類啊，不然蘇聯系列怎麼辦？  09/11 21:46
# ..                        ...          ...
# 18         放颱風假明明對喜歡上班的社畜更有利。  07/27 07:42
# 18          社畜颱風都是無薪假，上班哪有加班費  07/27 07:50
# 18            自己有放到就很爽 沒放就笑人家  07/27 08:45
# 18               現在都改WFH，沒有假了  07/27 08:53
# 19             我聽到的時候也想說幹怎麼可能  07/26 16:23
#
# [496 rows x 9 columns]

# %%
# 移除不必要的欄位後儲存文章內容
df.drop(["response", "留言列表"], axis=1).to_csv("ptt_joke_content.csv", index=False, encoding="utf-8-sig")
